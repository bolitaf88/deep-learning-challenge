# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Starter_Code/charity_data.csv")
application_df.head(11)
# Out:
#          EIN                                               NAME  \
# 0   10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1   10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2   10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3   10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4   10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# 5   10556855  MINORITY ORGAN & TISSUE TRANSPLANT & EDUCATION...
# 6   10558440  FRIENDS OF ARTS COUNCIL OF GREATER DENHAM SPRI...
# 7   10566033                          ISRAEL EMERGENCY ALLIANCE
# 8   10570430                                   ARAMCO BRATS INC
# 9   10571689         INTERNATIONAL ASSOCIATION OF FIRE FIGHTERS
# 10  10573059                      KAI ELUA OUTRIGGER CANOE CLUB
#
#    APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T10       Independent          C1000    ProductDev
# 1                T3       Independent          C2000  Preservation
# 2                T5  CompanySponsored          C3000    ProductDev
# 3                T3  CompanySponsored          C2000  Preservation
# 4                T3       Independent          C1000     Heathcare
# 5                T3       Independent          C1200  Preservation
# 6                T3       Independent          C1000  Preservation
# 7                T3       Independent          C2000  Preservation
# 8                T7       Independent          C1000    ProductDev
# 9                T5  CompanySponsored          C3000    ProductDev
# 10               T3       Independent          C1200  Preservation
#
#     ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0    Association       1              0                      N     5000
# 1   Co-operative       1         1-9999                      N   108590
# 2    Association       1              0                      N     5000
# 3          Trust       1    10000-24999                      N     6692
# 4          Trust       1  100000-499999                      N   142590
# 5          Trust       1              0                      N     5000
# 6          Trust       1  100000-499999                      N    31452
# 7          Trust       1        10M-50M                      N  7508025
# 8          Trust       1         1-9999                      N    94389
# 9    Association       1              0                      N     5000
# 10         Trust       1    25000-99999                      N    69656
#
#     IS_SUCCESSFUL
# 0               1
# 1               1
# 2               0
# 3               1
# 4               1
# 5               1
# 6               1
# 7               1
# 8               1
# 9               0
# 10              0

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df = application_df.drop(["EIN", "NAME"], axis = 1)

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
app_count= application_df["APPLICATION_TYPE"].value_counts()
app_count
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE

application_types_to_replace = app_count[app_count<500].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
class_count = application_df["CLASSIFICATION"].value_counts()
class_count
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
class_count[class_count>1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE

classifications_to_replace = class_count[class_count<1883].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
dummies_df =pd.get_dummies(application_df)
dummies_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y=dummies_df["IS_SUCCESSFUL"].values 
X=dummies_df.drop("IS_SUCCESSFUL", axis = 1)
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state= 42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_layer = len(X_train_scaled[0])
hidden_layer_1= 80
hidden_layer_2 = 30

# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_layer_1, activation="relu", input_dim = input_layer))

# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_layer_2, activation="relu"))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 80)                3520
#
#  dense_4 (Dense)             (None, 30)                2430
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer= "adam", metrics=["accuracy"])

# %%
# Train The Model
# YOUR CODE HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 719/719 [==============================] - 2s 3ms/step - loss: 0.5333 - accuracy: 0.7413
# Epoch 2/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7416
# Epoch 3/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7406
# Epoch 4/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7419
# Epoch 5/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7413
# Epoch 6/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7414
# Epoch 7/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7415
# Epoch 8/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7423
# Epoch 9/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7409
# Epoch 10/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7416
# Epoch 11/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7421
# Epoch 12/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7416
# Epoch 13/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7416
# Epoch 14/100
# 719/719 [==============================] - 2s 3ms/step - loss: 0.5326 - accuracy: 0.7411
# Epoch 15/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7417
# Epoch 16/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7416
# Epoch 17/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7407
# Epoch 18/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7420
# Epoch 19/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7413
# Epoch 20/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7410
# Epoch 21/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7414
# Epoch 22/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7416
# Epoch 23/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7416
# Epoch 24/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7412
# Epoch 25/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7417
# Epoch 26/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7417
# Epoch 27/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7418
# Epoch 28/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7414
# Epoch 29/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7414
# Epoch 30/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7415
# Epoch 31/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7415
# Epoch 32/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7411
# Epoch 33/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7413
# Epoch 34/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5319 - accuracy: 0.7415
# Epoch 35/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7416
# Epoch 36/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7416
# Epoch 37/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7418
# Epoch 38/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7416
# Epoch 39/100
# 719/719 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.7409
# Epoch 40/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7418
# Epoch 41/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7415
# Epoch 42/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7419
# Epoch 43/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7413
# Epoch 44/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7408
# Epoch 45/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7415
# Epoch 46/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7413
# Epoch 47/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7418
# Epoch 48/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7415
# Epoch 49/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7422
# Epoch 50/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7420
# Epoch 51/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7419
# Epoch 52/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7414
# Epoch 53/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7421
# Epoch 54/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7418
# Epoch 55/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7419
# Epoch 56/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7420
# Epoch 57/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7420
# Epoch 58/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7427
# Epoch 59/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7421
# Epoch 60/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7426
# Epoch 61/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7423
# Epoch 62/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7420
# Epoch 63/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7420
# Epoch 64/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7422
# Epoch 65/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7419
# Epoch 66/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7424
# Epoch 67/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7417
# Epoch 68/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5314 - accuracy: 0.7419
# Epoch 69/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7420
# Epoch 70/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7419
# Epoch 71/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5317 - accuracy: 0.7424
# Epoch 72/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7423
# Epoch 73/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7424
# Epoch 74/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7415
# Epoch 75/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5313 - accuracy: 0.7417
# Epoch 76/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5308 - accuracy: 0.7426
# Epoch 77/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5313 - accuracy: 0.7421
# Epoch 78/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7421
# Epoch 79/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7417
# Epoch 80/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7424
# Epoch 81/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5316 - accuracy: 0.7415
# Epoch 82/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7423
# Epoch 83/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7425
# Epoch 84/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7423
# Epoch 85/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7426
# Epoch 86/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7425
# Epoch 87/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7423
# Epoch 88/100
# 719/719 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7419
# Epoch 89/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5314 - accuracy: 0.7423
# Epoch 90/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5308 - accuracy: 0.7420
# Epoch 91/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5312 - accuracy: 0.7424
# Epoch 92/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5308 - accuracy: 0.7428
# Epoch 93/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5311 - accuracy: 0.7417
# Epoch 94/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5309 - accuracy: 0.7424
# Epoch 95/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5316 - accuracy: 0.7416
# Epoch 96/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5310 - accuracy: 0.7419
# Epoch 97/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5309 - accuracy: 0.7423
# Epoch 98/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5310 - accuracy: 0.7424
# Epoch 99/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5309 - accuracy: 0.7418
# Epoch 100/100
# 719/719 [==============================] - 1s 2ms/step - loss: 0.5311 - accuracy: 0.7420

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 354/354 - 1s - loss: 0.5618 - accuracy: 0.7253 - 631ms/epoch - 2ms/step
# Loss: 0.5618221759796143, Accuracy: 0.7253291010856628

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("./modelKERAS.keras")

# Rest of your code remains unchanged

plot_df = pd.DataFrame(fit_model.history, index=range(1, len(fit_model.history['loss']) + 1))
plot_df.plot(y='accuracy')
# Out:
# <Axes: >
